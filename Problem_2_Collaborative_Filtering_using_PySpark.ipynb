# %% [markdown]
# # Prepare environment

# %%
# !apt update
# !apt-get install openjdk-8-jdk-headless -qq > /dev/null
# !wget -q http://archive.apache.org/dist/spark/spark-3.1.2/spark-3.1.2-bin-hadoop2.7.tgz
# !tar xf spark-3.1.2-bin-hadoop2.7.tgz
# !pip install -q findspark
import os
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
os.environ["SPARK_HOME"] = "/content/spark-3.1.2-bin-hadoop2.7"
import findspark
findspark.init()
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease [3,626 B]
# Ign:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Get:3 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Ign:4 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Get:5 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release [696 B]
# Hit:6 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Get:7 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release.gpg [836 B]
# Get:8 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease [15.9 kB]
# Hit:10 http://archive.ubuntu.com/ubuntu bionic InRelease
# Get:11 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Packages [829 kB]
# Get:12 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Hit:13 http://ppa.launchpad.net/cran/libgit2/ubuntu bionic InRelease
# Hit:14 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic InRelease
# Get:15 http://security.ubuntu.com/ubuntu bionic-security/main amd64 Packages [2,461 kB]
# Get:16 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [74.6 kB]
# Get:17 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease [21.3 kB]
# Get:18 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 Packages [2,898 kB]
# Get:19 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main Sources [1,814 kB]
# Get:20 http://security.ubuntu.com/ubuntu bionic-security/universe amd64 Packages [1,444 kB]
# Get:21 http://security.ubuntu.com/ubuntu bionic-security/restricted amd64 Packages [691 kB]
# Get:22 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 Packages [2,225 kB]
# Get:23 http://archive.ubuntu.com/ubuntu bionic-updates/restricted amd64 Packages [725 kB]
# Get:24 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main amd64 Packages [931 kB]
# Get:25 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic/main amd64 Packages [44.7 kB]
# Fetched 14.4 MB in 7s (2,008 kB/s)
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# 53 packages can be upgraded. Run 'apt list --upgradable' to see them.

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %cd '/content/gdrive/MyDrive/LDS02_k271_NguyenMinhQuan/Problem_3_RecomendationSystem_TikiOnlineShopping'
# Out:
# /content/gdrive/MyDrive/LDS02_k271_NguyenMinhQuan/Problem_3_RecomendationSystem_TikiOnlineShopping

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime
import statistics as stats
import math

# Import PySpark related modules
import pyspark
from pyspark.rdd import RDD
from pyspark.sql import Row
from pyspark.sql import DataFrame
from pyspark.sql import SparkSession
from pyspark.sql import SQLContext
from pyspark.sql import functions
from pyspark.sql.functions import lit, desc, col, size, array_contains,\
isnan, udf, hour, array_min, array_max, countDistinct, regexp_extract, count, when
from pyspark.sql.functions import avg, struct, sum, explode
from pyspark.sql.types import *

from pyspark.ml.feature import Binarizer
from pyspark.ml.feature import QuantileDiscretizer
from pyspark.ml.feature import OneHotEncoder, StringIndexer
from pyspark.ml.feature import StandardScaler
from pyspark.ml.stat import ChiSquareTest

#Pysark ml
from pyspark.ml.linalg import Vectors
from pyspark.ml.feature import VectorAssembler
from pyspark.ml.classification import DecisionTreeClassifier
from pyspark.ml.classification import RandomForestClassifier, GBTClassifier
from pyspark.ml import Pipeline

from pyspark.ml.recommendation import ALS
from pyspark.ml.evaluation import RegressionEvaluator


#Support function
def show_head(df):
  display(df.limit(5).toPandas())

def check_null(df):
    df.select([count(when(isnan(c) | df[c].isNull(), c)).alias(c) for c in df.columns]).show()

# %%
MAX_MEMORY = '12G'
# Initialize a spark session.
conf = pyspark.SparkConf().setMaster("local[*]") \
        .set('spark.executor.heartbeatInterval', 10000) \
        .set('spark.network.timeout', 10005) \
        .set("spark.core.connection.ack.wait.timeout", "3600") \
        .set("spark.executor.memory", MAX_MEMORY) \
        .set("spark.driver.memory", MAX_MEMORY)
def init_spark(appName):
    spark = SparkSession \
        .builder \
        .appName(appName) \
        .config(conf=conf) \
        .getOrCreate()
    spark.sparkContext.setCheckpointDir('/content/gdrive/MyDrive/LDS02_k271_NguyenMinhQuan/Problem_3_RecomendationSystem_TikiOnlineShopping/spark_checkpoints')
    return spark

spark = init_spark("Tiki collaborative filtering")
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://d417a89aa8ed:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.1.2</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Tiki collaborative filtering</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %% [markdown]
# # Step 1: Define Problem
#
# ### Context
# Assume that our company is a online retail shopping, names Tiki, and it has not been built a recommendation system yet. Now Tiki want to build a recommendation system, to help the customers of the company have more pleasure to buy things on our shop.
#
# And this is our task, they said.
#
# #### Objective:
# Building a recommendation system using ML algorithm.
#
# #### Job to do:
# We will build two type of recommendation system:
# 1. Content base recommendation (recommending base on the similarity of products)
# 2. Collaborative filtering (recommending base on the similarity of behaviors of customers)
#
# + Content base recomendation (Gợi ý dựa trên sự tương đồng giữa các sản phẩm)
# + Collaborative filtering recomendation (Gợi ý dựa trên sự tương đồng và hành vi của các khách hàng với nhau)
#
# In this notebook we solve problem 2 : Collaborative filtering using PySpark

# %% [markdown]
# # Step 2: Data gathering, understanding

# %% [markdown]
# The data was gave to us at "ReviewRaw.csv" with the following description:
# 1. customer_id: Customer's id
# 2. product_id: Product's id
# 3. name: customer's last name
# 4. full_name: customer's full name
# 5. create_time: the time when the record was created
# 6. rating: the number of star was rated in range (1 - 5)
# 7. title: title of the review
# 8. content: content of the review

# %%
data = spark.read.csv('/content/gdrive/MyDrive/LDS02_k271_NguyenMinhQuan/Problem_3_RecomendationSystem_TikiOnlineShopping/ReviewRaw.csv',
                      header=True, inferSchema=True).cache()
data.show(5)
# Out:
# +-----------+----------+-----------------+----------------+-------------------+------+------------------+--------------------+
# |customer_id|product_id|             name|       full_name|       created_time|rating|             title|             content|
# +-----------+----------+-----------------+----------------+-------------------+------+------------------+--------------------+
# |     709310|  10001012| Lân Nguyễn Hoàng|Lân Nguyễn Hoàng|               null|     3|Ko dùng đc thẻ nhớ|Lúcđầu quên thông...|
# |   10701688|  10001012| Nguyễn Khánh Hòa|Nguyễn Khánh Hòa|               null|     5|   Cực kì hài lòng|Tiki giao hàng nh...|
# |   11763074|  10001012|  Toàn Phạm Khánh| Toàn Phạm Khánh|2019-04-17 15:42:45|     5|   Cực kì hài lòng|chất lượng camera...|
# |    9909549|  10001012|Nguyen Quang Minh|            null|               null|     5|      Rất hài lòng|Hàng được đóng gó...|
# |    1827148|  10001012|      Phạm Bá Đức|     Phạm Bá Đức|               null|     5|   Cực kì hài lòng|dễ cài đặt, chất ...|
# +-----------+----------+-----------------+----------------+-------------------+------+------------------+--------------------+
# only showing top 5 rows

# %% [markdown]
# # Step 3: Preprocessing Data
# Because I will use ALS algorithm to build recommendation system, so i will only keep these useful for our model: customer_id, product_id, rating.
#
# The preprocessing steps will go as following steps:
# 1. Remove duplicate data
# 2. Remove missung data
# 3. Cast data type

# %%
#Select useful columns for collaborative filtering  algothirm
data = data[['customer_id', 'product_id', 'rating' ]]
data.printSchema()
# Out:
# root
#  |-- customer_id: string (nullable = true)
#  |-- product_id: string (nullable = true)
#  |-- rating: string (nullable = true)

# %%
print(f'There are total {data.count()} records')
# Out:
# There are total 365821 records

# %%
#Drop duplicate data
data = data.drop_duplicates(subset=['customer_id', 'product_id'])

# %%
print(f'There are total {data.count()} records after drop duplicates')
# Out:
# There are total 361121 records after drop duplicates

# %%
#Detect missing values
check_null(data)
# Out:
# +-----------+----------+------+
# |customer_id|product_id|rating|
# +-----------+----------+------+
# |          1|       783|  1618|
# +-----------+----------+------+

# %%
#Drop misssing values
data = data.dropna()
check_null(data)
# Out:
# +-----------+----------+------+
# |customer_id|product_id|rating|
# +-----------+----------+------+
# |          0|         0|     0|
# +-----------+----------+------+

# %%
#Cast columns type
data = data.withColumn('rating', data['rating'].cast(FloatType()))
#Overview data
data.describe().show()
# Out:
# +-------+--------------------+--------------------+------------------+
# |summary|         customer_id|          product_id|            rating|
# +-------+--------------------+--------------------+------------------+
# |  count|              359503|              359503|            359451|
# |   mean|   9170476.046532072|2.4342564193709295E7| 4.473725208721078|
# | stddev|   6307651.621988519|2.3756596933877297E7|1.0184288775309063|
# |    min|- 4/12/2020: Tiki...| 13.000mAh thì mì...|               1.0|
# |    max|        Ưu điểm: Nhỏ|             9996258|               5.0|
# +-------+--------------------+--------------------+------------------+

# %%
#Select records where customer_id and product_id is not numberical
temp = data.filter(
    (data.customer_id.rlike('\D+')) | 
     (data.product_id.rlike('\D+'))
     )

print(f"There are total {temp.count()} invalid records")
temp.show(52)
# Out:
# There are total 52 invalid records
# +--------------------+--------------------+------+
# |         customer_id|          product_id|rating|
# +--------------------+--------------------+------+
# |Bàm phím theo mìn...|      không ồn nhiều|  null|
# |- Đầu tiên là về ...| 13.000mAh thì mì...|  null|
# |Vẫn thiết kế nhỏ ...| vừa không gây bí...|  null|
# |Sau một thời gian...| mình thấy ổ cứng...|  null|
# |             Tóm lại| ước gì mình đã k...|  null|
# |  Về thiết kế sp đẹp| nhìn khá sang trọng|  null|
# |Con này là bản A2...| đẹp hơn hộp đợt ...|  null|
# |Giá quá ưu đãi ch...|      dung lượng cao|  null|
# |Xét tổng quan thì...| gia công tốt bên...|  null|
# | Bao da tặng kèm đẹp| bỏ ổ cứng vô nhì...|  null|
# |Tai nghe này hình...|             gọn nhẹ|  null|
# |   Về mặt dung lượng| 500gb không nhiề...|  null|
# |Về chất lượng âm ...|                 5tr|  null|
# |2. Về Anker: cục ...|                 đẹp|  null|
# |           - Giá rẻ |     dung lượng lớn |  null|
# |Bàn phím phổ thôn...| tuy nhien nút En...|  null|
# |Sản phẩm nhận đượ...| nhưng cũng không...|  null|
# |    Sản phẩm màu đen|                bóng|  null|
# |         Về âm thanh| tai nghe này có ...|  null|
# |        Còn với tiki| như những lần trước|  null|
# |Âm thanh nghe khá...| k rè tuy nhiên m...|  null|
# |Riêng về sản phẩm...| mình mua 1 em mà...|  null|
# |Chuột được thiết ...|     trọng lượng nhẹ|  null|
# |- Thường thì như ...| còn bàn phím này...|  null|
# |Sản phẩm new full...| tem bảo hành đầy đủ|  null|
# |Thích nhất là chứ...| chỉ cần cắm thẻ ...|  null|
# |  Chất lượng loa khá| nghe nhạc kiểu c...|  null|
# |   Gọi tiki đổi hàng| qua đến tuần sau...|  null|
# |Tôi có đặt thêm d...| tuy nhiên nhân v...|  null|
# |        Ưu điểm: Nhỏ|                 gọn|  null|
# |   Kiểu dáng gọn nhẹ|            đơn giản|  null|
# |         Âm thanh ổn| thích hợp cho họ...|  null|
# |  Âm thanh: tạm được| thích hợp trong ...|  null|
# | Bàn phím thì hơi dở| phím tuy bấm mềm...|  null|
# |Nhưng có điều là ...| click chuột sẽ n...|  null|
# |- Vỏ nhựa của Pin...|       tránh rò điện|  null|
# |Trước giờ đều rất...| lần này do chính...|  null|
# |USB có thiết kế n...| vỏ kim loại sáng...|  null|
# |Về chất lượng sản...|         loa nhỏ gọn|  null|
# |Về bàn phím: bàn ...| để yên thì nhìn ...|  null|
# |         - Tiếp theo| một vấn đề mà mì...|  null|
# |Phần thiết kế rất...| lớp vỏ ngoài nhá...|  null|
# |Hiệu năng rất ổn ...| ở một vài dòng m...|  null|
# |Nói chung chất lư...| nếu rành về nhiế...|  null|
# |       - Về sản phẩm| tai nghe chỉ ngh...|  null|
# |Nhận viên Tiki tr...| thu lượm toàn bộ...|  null|
# |     Dùng điện thoại|   đứng ở giữa 2 con|  null|
# |- 4/12/2020: Tiki...| vì chỉ có 2 ngườ...|  null|
# |Mình sẽ xem xét v...| cũng như tự thử ...|  null|
# |- 5/12/2020: Nhân...| dự trù thời gian...|  null|
# |Bây giờ xin nói v...| nút bấn có độ êm...|  null|
# |- Mình đã mua khá...| và đa số đều là ...|  null|
# +--------------------+--------------------+------+

# %%
data = data.filter(
    ~(data.customer_id.rlike('\D+')) &
     ~(data.product_id.rlike('\D+'))
     )
data.describe().show()
# Out:
# +-------+-----------------+--------------------+------------------+
# |summary|      customer_id|          product_id|            rating|
# +-------+-----------------+--------------------+------------------+
# |  count|           359451|              359451|            359451|
# |   mean|9170476.046532072|2.4342564193709295E7| 4.473725208721078|
# | stddev|6307651.621988519|2.3756596933877297E7|1.0184288775309063|
# |    min|               10|            10001012|               1.0|
# |    max|          9999890|             9996258|               5.0|
# +-------+-----------------+--------------------+------------------+

# %%
users_count = data.select('customer_id').distinct().count()
items_count = data.select('product_id').distinct().count()
numerator = data.count()

print(f"Sparsity: {1-(numerator/users_count/items_count):.2f}")
print(f'Number of users: {users_count}')
print(f'Number of items: {items_count}')
# Out:
# Sparsity: 1.00
# Number of users: 251467
# Number of items: 4218

# %% [markdown]
# The number of customers is greater five times than the number of products. That mean these products are quite attractive

# %%
#indexer string columns
data = data.withColumn('customer_id', data['customer_id'].cast(LongType()))
data = data.withColumn('product_id', data['product_id'].cast(LongType()))
data.printSchema()
# Out:
# root
#  |-- customer_id: long (nullable = true)
#  |-- product_id: long (nullable = true)
#  |-- rating: float (nullable = true)

# %%
user_col = 'customer_id'
item_col = 'product_id'
rating_col = 'rating'

# %% [markdown]
# # Step 4: Building model

# %% [markdown]
# ### Choose the best pramaters for our model

# %%
from pyspark.ml.tuning import ParamGridBuilder, CrossValidator, CrossValidatorModel, TrainValidationSplit

# %%
#Take a piece of data for tunning, because fit all dataset will break my ram
train, test = data.select([user_col, item_col, rating_col]).sample(fraction = 0.8, seed = 2021).randomSplit([0.7, 0.2], seed = 2021)

# %%
#Init model
als = ALS(userCol = user_col, itemCol = item_col, ratingCol = rating_col,
    nonnegative=True, coldStartStrategy='drop', implicitPrefs = False
)
#Defind params grid
paramsGrid = ParamGridBuilder()\
                        .addGrid(als.rank, [10, 50, 100]) \
                        .addGrid(als.maxIter, [10, 50]) \
                        .addGrid(als.regParam, [.01, .05, .1]) \
                        .build()

# %%
tvs = TrainValidationSplit(estimator=als,
                           estimatorParamMaps=paramsGrid,
                           evaluator=RegressionEvaluator(labelCol='rating'),
                           trainRatio=0.7,
                           parallelism=65)
model = tvs.fit(train)

# %% [markdown]
# Total estimation time was 42 mins

# %%
predictions = model.bestModel.transform(text)
show_head(predictions)
# Out:
#    customer_id  product_id  rating  prediction
# 0      7523016     1675793     5.0    3.968034
# 1     11840091     2069769     3.0    3.432528
# 2      7681066     2086067     5.0    3.990786
# 3     12577003     2086067     5.0    3.867913
# 4         5235     2774881     5.0    4.466080

# %%
#Evaluate model
evaluator = RegressionEvaluator(labelCol=rating_col)
print(f"RMSE: {evaluator.evaluate(predictions):.2f}")
# Out:
# RMSE: 1.18

# %%
#Statistic overview rating columns
text.select('rating').describe().show()
# Out:
# +-------+------------------+
# |summary|            rating|
# +-------+------------------+
# |  count|             64031|
# |   mean| 4.476066280395433|
# | stddev|1.0139667440765376|
# |    min|               1.0|
# |    max|               5.0|
# +-------+------------------+

# %% [markdown]
# The RMSE = 1.18 is not quite good on the range rating (1-5). But it can also show some information to recommend customers.

# %%
model.bestModel.rank
# Out:
# 100

# %%
(model.bestModel
    ._java_obj     # Get Java object
    .parent()      # Get parent (ALS estimator)
    .getMaxIter()) # Get maxIter
# Out:
# 50

# %%
(model.bestModel
    ._java_obj     # Get Java object
    .parent()      # Get parent (ALS estimator)
    .getRegParam()) # Get getRegParam
# Out:
# 0.1

# %%
#Fit model to all dataset with best param
als = ALS(
    userCol = user_col,
    itemCol = item_col,
    ratingCol = rating_col,
    nonnegative=True,
    coldStartStrategy='drop',
    implicitPrefs = False,
    rank = 100, regParam = 0.1, maxIter = 50
).fit(data)

# %%
test_data = data.sample(False,0.0001, 2022)
test_data.count()
# Out:
# 38

# %%
recommends = als.recommendForUserSubset(test_data, numItems=5)
recommends.show( truncate=False)
# Out:
# +-----------+---------------------------------------------------------------------------------------------------------------------+
# |customer_id|recommendations                                                                                                      |
# +-----------+---------------------------------------------------------------------------------------------------------------------+
# |16133138   |[{74227763, 4.986838}, {76732229, 4.941821}, {19395453, 4.909876}, {48520298, 4.871111}, {67985251, 4.84216}]        |
# |15808261   |[{25171293, 1.9515743}, {15287960, 1.8828714}, {19420381, 1.8732599}, {76732229, 1.8670377}, {187278, 1.848959}]     |
# |5650336    |[{76732229, 5.0044746}, {11191145, 4.888131}, {19395453, 4.747975}, {67985251, 4.7458663}, {50592901, 4.696976}]     |
# |6325137    |[{76732229, 4.753544}, {1819263, 4.66037}, {19395453, 4.6191115}, {13392137, 4.5540023}, {53751834, 4.526345}]       |
# |15533534   |[{76732229, 5.14967}, {19395453, 5.031311}, {2383179, 5.001319}, {50692303, 4.9460897}, {51501467, 4.8967185}]       |
# |5249891    |[{76732229, 5.074637}, {19395453, 4.8404694}, {73238633, 4.8216586}, {44232899, 4.7862725}, {15287960, 4.7826533}]   |
# |6521591    |[{591960, 3.913469}, {76732229, 3.8609438}, {70631732, 3.7860038}, {74911967, 3.7708743}, {589301, 3.6458826}]       |
# |1195127    |[{76732229, 5.808035}, {19395453, 5.371673}, {67985251, 5.322826}, {58962575, 5.2948575}, {44012841, 5.2609286}]     |
# |20126931   |[{48102821, 3.9082973}, {76732229, 3.8724186}, {72119221, 3.7786102}, {76126279, 3.7766514}, {65948026, 3.7322822}]  |
# |8364646    |[{20200144, 4.894802}, {76732229, 4.8011656}, {19395453, 4.6409035}, {10001353, 4.5802503}, {74274442, 4.5780454}]   |
# |14178849   |[{50560427, 5.1415596}, {70524690, 4.898788}, {76732229, 4.890792}, {56306151, 4.8745275}, {54485907, 4.8213553}]    |
# |12374852   |[{76732229, 5.3221803}, {19395453, 5.1031723}, {67985251, 4.9412365}, {74274442, 4.9400835}, {7319551, 4.9365726}]   |
# |8506034    |[{76732229, 4.222562}, {19395453, 4.1224976}, {67985251, 4.107719}, {50592901, 4.0190396}, {71938164, 3.9648702}]    |
# |818746     |[{76732229, 5.5979548}, {19395453, 5.37446}, {67985251, 5.293516}, {73238633, 5.2518373}, {50796737, 5.245302}]      |
# |12930982   |[{20884713, 4.8934617}, {76732229, 4.7417436}, {14071985, 4.5743513}, {67985251, 4.480538}, {38458616, 4.479793}]    |
# |18109788   |[{21857291, 0.97741383}, {73238633, 0.9539134}, {76732229, 0.9282616}, {15287960, 0.9219683}, {19395453, 0.91758764}]|
# |11503306   |[{76732229, 5.255567}, {19395453, 5.0393457}, {15287960, 4.9300795}, {74274442, 4.9063373}, {50592901, 4.901627}]    |
# |867319     |[{76732229, 4.9293923}, {8141868, 4.8960676}, {13607810, 4.8692956}, {19395453, 4.719779}, {6039457, 4.6722093}]     |
# |11223890   |[{548549, 4.893223}, {68521343, 4.8457494}, {19395453, 4.7638683}, {31820638, 4.7393317}, {68527587, 4.712607}]      |
# |1979785    |[{76732229, 5.423974}, {19395453, 5.2871523}, {67985251, 5.1591263}, {73238633, 5.148297}, {50592901, 5.0966153}]    |
# +-----------+---------------------------------------------------------------------------------------------------------------------+
# only showing top 20 rows

# %%
product_recommeds = als.recommendForItemSubset(test_data, numUsers=5)
product_recommeds.show( truncate=False)
# Out:
# +----------+------------------------------------------------------------------------------------------------------------------+
# |product_id|recommendations                                                                                                   |
# +----------+------------------------------------------------------------------------------------------------------------------+
# |56799621  |[{5501942, 5.159139}, {1230935, 5.0629935}, {16284452, 5.0166187}, {16876819, 5.0166187}, {19323492, 4.9607573}]  |
# |249953    |[{5501942, 5.677355}, {18185771, 5.413895}, {1230935, 5.3004174}, {5758917, 5.286437}, {10770051, 5.242272}]      |
# |11191145  |[{18185771, 5.017337}, {5501942, 5.017262}, {6437047, 4.926277}, {1230935, 4.922798}, {15103000, 4.888131}]       |
# |25171293  |[{14857161, 4.8801656}, {13537371, 4.8801656}, {15668016, 4.8801656}, {16459380, 4.878936}, {16554170, 4.878936}] |
# |11794382  |[{5501942, 4.9889393}, {18185771, 4.957399}, {2007830, 4.892455}, {1013140, 4.892455}, {6159950, 4.892455}]       |
# |591960    |[{10770051, 5.1704803}, {12802704, 5.0567026}, {18185771, 4.9843025}, {16128798, 4.9391775}, {5501942, 4.9317617}]|
# |405243    |[{1230935, 5.1696663}, {10770051, 5.1561084}, {11078076, 5.1406317}, {13109053, 5.131701}, {18185771, 5.115911}]  |
# |55596971  |[{5501942, 5.4958644}, {1230935, 5.301319}, {10770051, 5.285792}, {18185771, 5.2599397}, {11185142, 5.258267}]    |
# |21857291  |[{10381510, 4.8870683}, {10084710, 4.8870683}, {1286000, 4.8870683}, {11236470, 4.8870683}, {10013780, 4.8870683}]|
# |6010061   |[{5501942, 5.4987226}, {18185771, 5.4118285}, {1230935, 5.4077578}, {13109053, 5.361212}, {11185142, 5.3207383}]  |
# |43107185  |[{5501942, 5.4698625}, {1230935, 5.32524}, {18185771, 5.1892114}, {13109053, 5.163164}, {10770051, 5.100288}]     |
# |27609946  |[{5501942, 5.597212}, {1230935, 5.3974385}, {10770051, 5.295195}, {6437047, 5.27698}, {12540834, 5.2462773}]      |
# |416985    |[{18185771, 4.951703}, {2196297, 4.9419045}, {12866051, 4.9082823}, {15880486, 4.902877}, {1831450, 4.8994412}]   |
# |465219    |[{18185771, 5.2148848}, {5501942, 5.03315}, {13109053, 5.02269}, {18328021, 4.996283}, {19234967, 4.996283}]      |
# |20884713  |[{5501942, 5.1819363}, {18185771, 4.934847}, {14852891, 4.9159503}, {15081211, 4.894544}, {19003668, 4.8937654}]  |
# |3939221   |[{5501942, 5.5220246}, {1230935, 5.349457}, {13109053, 5.2047462}, {16284452, 5.1655016}, {16876819, 5.1655016}]  |
# |8159799   |[{10770051, 5.542798}, {18185771, 5.3477364}, {11078076, 5.300508}, {13109053, 5.1907215}, {5501942, 5.173184}]   |
# |5950363   |[{11078076, 5.3599486}, {10770051, 5.212212}, {13109053, 5.109692}, {5501942, 5.058238}, {18185771, 5.041744}]    |
# |20200144  |[{5501942, 5.1716285}, {1230935, 5.1282134}, {13109053, 5.0194583}, {18185771, 4.9981613}, {19323492, 4.993012}]  |
# |62263771  |[{5501942, 5.6666565}, {1230935, 5.469643}, {18185771, 5.43704}, {11185142, 5.3730507}, {10770051, 5.358873}]     |
# +----------+------------------------------------------------------------------------------------------------------------------+
# only showing top 20 rows

# %% [markdown]
# # Step 5: Report
# The recommendation systen was bulding by ALS, giving the RMSE score = 1.18 on test set. On overall our model can recommend which products are most likely to be bought by the customer X. But the model only recommend customers which in ReviewRaw.csv file.
#
# When recommend, we need to feed the model the customer's id, and then our model will answer what product's id that customer will buy next.

# %%
#Save model for later use
als.save('/content/gdrive/MyDrive/LDS02_k271_NguyenMinhQuan/Problem_3_RecomendationSystem_TikiOnlineShopping/collaborative_filtering_model')

# %%
#Save clean data
data.toPandas().to_csv("/content/gdrive/MyDrive/LDS02_k271_NguyenMinhQuan/Problem_3_RecomendationSystem_TikiOnlineShopping/review_clean.csv")

# %%
spark.stop()
